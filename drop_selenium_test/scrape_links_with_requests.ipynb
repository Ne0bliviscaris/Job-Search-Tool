# %% [markdown]
# theprotocol.it - scrape url

# %%
import httpx
from bs4 import BeautifulSoup
url = "https://theprotocol.it/filtry/python;t/big-data-science,ai-ml;sp/junior,assistant,trainee;p/zdalna;rw"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "pl-PL,pl;q=0.9,en-US;q=0.8,en;q=0.7"
}
protocol = httpx.get(url, headers=headers)
soup = BeautifulSoup(protocol.text, 'html.parser')
backdrop = soup.find("div", {"data-test": "backdrop"})
if backdrop:
    backdrop.parent.decompose()
scripts = soup.find_all("script")
for script in scripts:
    script.decompose()
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="pl"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><meta content="#85BCEE" name="theme-color"/><meta content="index, follow, all" name="robots"/><meta content="3RgRf9IoDsXtN-2fLfE1rRkV7QTQQvKEAdrlZbtbb98" name="google-site-verification"/><title>Praca w branży IT, Python, big data/data science, AI/ML, junior, assistant, trainee, praca zdalna - theprotocol.it</title><meta content="Odwiedź theprotocol.it i aplikuj na oferty pracy IT, Python, big data/data science, AI/ML, junior, assistant, trainee, praca zdalna!" name="description"/><link href="https://theprotocol.it/filtry/python;t/big-data-science,ai-ml;sp/junior,assistant,trainee;p/zdalna;rw" rel="canonical"/><link href="https://static.theprotocol.it/statics/_favicons/favicon-64x64--dark.ico" rel="icon"/><link href="https://static.theprotocol.it/statics/_favicons/favicon-180x180--dark.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://static.theprotocol.it/statics/_favicons/favicon-32x32--dark.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://static.theprotocol.it/statics/_favicons/favicon-16x16--dark.png" rel="icon" sizes="16x16" type="image/png"/><meta content="Praca w branży IT - theprotocol.it" property="og:title"/><meta content="https://static.theprotocol.it/statics/_files/tp_social_media_card.png" property="og:image"/><meta content="https://theprotocol.it/?filters=%7B%22keywords%22%3A%5B%5D%2C%22technologies%22%3A%5B%22python%22%5D%2C%22specializations%22%3A%5B%22big-data-science%22%2C%22ai-ml%22%5D%2C%22positionLevels%22%3A%5B%22junior%22%2C%22assistant%22%2C%22trainee%22%5D%2C%22contracts%22%3A%5B%5D%2C%22salary%22%3A%5B%5D%2C%22locations%22%3A%5B%5D%2C%22regions%22%3A%5B%5D%2C%22workModes%22%3A%5B%22zdalna%22%5D%2C%22support%22%3A%5B%5D%2C%22context%22%3A%5B%5D%7D&amp;sub=" property="og:url"/><meta content="15" name="next-head-count"/><link href="https://static.theprotocol.it/statics/_css/fira-code.css" rel="stylesheet"/><link href="https://static.theprotocol.it/statics/_css/proxima-nova.css" rel="stylesheet"/><style>
#     :root {
#       --color-errorMain: #f61933;
#       --color-backgroundLight: #FFFBFC;
#       --color-backgroundWhite: #FFFFFF;
#       --color-backgroundWhiteViewed: #FFFCFD;
#       --color-backgroundWhiteSalaryMobile: #EBEFFF;
#       --color-backgroundGrey: #F2F2F2;
#       --color-backgroundSkeleton: #F6F2F3;
#       --color-backgroundActiveCard: #F7FEFA;
#       --color-backgroundChipsLight: #D8F8E8;
#       --color-backgroundErrorLight: #FA7585;
#       --color-backgroundErrorLighter: #FCB9C1;
#       --color-backgroundOverlayLight: #12182866;
#       --color-backgroundColumnLight: #F9FAFF;
#       --color-backgroundDark0Dp: #121828;
#       --color-backgroundDark1Dp: #1E2433;
#       --color-backgroundDark8Dp: #2E3442;
#       --color-backgroundDark24Dp: #383D4A;
#       --color-backgroundErrorDark: #FA7585;
#       --color-backgroundOverlayDark: #121828CC;
#       --color-backgroundColumnDark: #1B2538;
#       --color-backgroundDarkViewed: #171D2C;
#       --color-backgroundDarkSalaryMobile: #262C3B;
#       --color-mainPrimaryBlueLight: #3964FF;
#       --color-mainPrimaryBlueDarkerLight: #002ED4;
#       --color-mainPrimaryBlueLighterLight: #C4D1FF;
#       --color-mainHoverLight: #EBEFFF;
#       --color-mainHoverDarkerLight: #88A2FF;
#       --color-mainSecondaryGreenLight: #B1F1D1;
#       --color-mainSecondaryGreenDarkerLight: #0D884A;
#       --color-mainPrimaryBlueDark: #85BCEE;
#       --color-mainPrimaryBlueDarkerDark: #4E95D6;
#       --color-mainPrimaryBlueLighterDark: #C2DEF7;
#       --color-mainHoverDark: #283346;
#       --color-mainHoverDarkerDark: #3D526B;
#       --color-textPrimaryLight: #111C43;
#       --color-textSecondaryLight: #485071;
#       --color-textDisabledLight: #71718E;
#       --color-textPrimaryDark: #E0E1E3;
#       --color-textSecondaryDark: #A0A3A9;
#       --color-textDisabledDark: #898B90;
#       --color-greysStrokesLight: #E0E0E0;
#       --color-greysStrokesDisabledLight: #F2F2F2;
#       --color-greysIcons: #ABABAB;
#       --color-greysStrokesDark: #474C59;
#       --color-greysStrokesDisabledDark: #1E2433;
#       --color-actionsSuccessLight: #1CC973;
#       --color-actionsSuccessHoverLight: #E8FAF1;
#       --color-actionsWarningLight: #FF9800;
#       --color-actionsErrorLight: #F61933;
#       --color-actionsErrorHoverLight: #FEE8EB;
#       --color-actionsSuccessDark: #1CC973;
#       --color-actionsSuccessHoverDark: #132A30;
#       --color-actionsWarningDark: #FF9800;
#       --color-actionsErrorDark: #E4495B;
#       --color-actionsErrorHoverDark: #462B3B;
#       --color-othersGradientLight: linear-gradient(90deg, #B1F2D2 0%, #369FFF 100%);
#       --color-othersRecommendationsLight: #FFFBF0;
#       --color-othersAddInsLight: #F4F6FF;
#       --color-othersAddInsDark: #203047;
#       --color-othersGradientDark: linear-gradient(81.52deg, #B1F2D2 5.97%, #85BDEE 100%);
#       --color-othersRecommendationsDark: #2F1F32;
#       --color-othersBlack: #000000;
#       --color-othersFilterBackgroundLight: #EEF2FF;
#       --color-othersFilterHoverBackgroundLight: #DFE5FF;
#       --color-otherActiveBlueLight: #00A1FF;
#       --shadow-shadow1PLight: 0 0 30px 0 #e7d3d826, 0 4px 40px 0 #e7d3d814, 0 4px 4px 0 #e7d3d81a;
#       --shadow-shadow8PLight: 0 2px 10px #E7D3D8;
#       --shadow-shadow16PLight: 0px 4px 20px #E7D3D8;
#       --shadow-shadow24PLight: 0px 2px 10px #E7D3D8, 2px 8px 30px #E7D3D8;
#       --shadow-shadowX1Light: 0 0 0 30px #FFFFFF inset;
#       --shadow-shadow8PDark: 0px 2px 10px #121828;
#       --shadow-shadowX1Dark: inset 1px 1px 12px 18px #616161;
#       --shadow-shadowX2Dark: 0 0 30px 0 #1E2433;
#       --shadow-shadowX3Dark: 0 3px 3px -2px rgb(0 0 0 / 20%), 0 3px 4px 0 rgb(0 0 0 / 14%), 0 1px 8px 0 rgb(0 0 0 / 12%);
#       --shadow-shadowX4Dark: 0 3px 1px -2px rgb(0 0 0 / 20%), 0 2px 2px rgb(0 0 0 / 14%), 0 1px 5px rgb(0 0 0 / 12%);
#       --shadow-shadowX5Dark: 0 0 0 30px #1E2433 inset;
#       --shadow-shadowX6Dark: 0px 0px 30px 0px #04061F4D;
#       --shadow-shadowX7Dark: 0 0 0 30px #121828 inset;
#       --shadow-shadowBlueDark: 0 0 8px 0 rgb(0 161 255 / 40%);
#       --paletteType: dark;
#     }
#
#
#   html {
#     box-sizing: border-box;
#     scrollbar-color: #CECCDE;
#     scrollbar-width: thin;
#     -webkit-font-smoothing: antialiased;
#     -moz-osx-font-smoothing: grayscale;
#   }
#   *, *::before, *::after {
#     box-sizing: inherit;
#   }
#   strong, b {
#     font-weight: 700;
#   }
#   body {
#     color: var(--color-textPrimaryLight);
#     margin: 0;
#     padding: 0;
#     font-size: .875rem;
#     font-family: proxima-nova, serif;
#     font-weight: 500;
#     line-height: 1.43;
#     overflow-wrap: break-word;
#     background-color: #fffbfc;
#   }
#   @media print {
#     body {
#       background-color: #fff;
#     }
#   }
#
#   body[data-theme='dark'] {
#     background-color: #121828;
#     color: #fff;
#   }
#   body::backdrop {
#     background-color: #303030;
#   }
#   *::-webkit-scrollbar {
#     width: 8px;
#     height: 5px;
#     margin: 0;
#     padding: 0;
#   }
#   *::-webkit-scrollbar-thumb {
#     border-radius: 6px;
#     background-color: #CECCDE;
#   }
#   * {
#     box-sizing: border-box;
#   }
#   p {
#     margin: 13px 0;
#   }
#   .grecaptcha-badge {
#     visibility: hidden;
#   }
#   button {
#     font-weight: 500;
#   }
#
#   </style><link as="style" href="https://tahirihhira.gpcdn.pl/offers/prod/375955/_next/static/css/8409d6afb393baf8.css" rel="preload"/><link data-n-g="" href="https://tahirihhira.gpcdn.pl/offers/prod/375955/_next/static/css/8409d6afb393baf8.css" rel="stylesheet"/><link as="style" href="https://tahirihhira.gpcdn.pl/offers/prod/375955/_next/static/css/ae4bf5a1ade649dc.css" rel="preload"/><link data-n-p="" href="https://tahirihhira.gpcdn.pl/offers/prod/375955/_next/static/css/ae4bf5a1ade649dc.css" rel="stylesheet"/><link as="style" href="https://tahirihhira.gpcdn.pl/offers/prod/375955/_next/static/css/90629a92c3610117.css" rel="preload"/><link data-n-p="" href="https://tahirihhira.gpcdn.pl/offers/prod/375955/_next/static/css/90629a92c3610117.css" rel="stylesheet"/><noscript data-n-css=""></noscript></head><body data-theme="dark"><div id="__next"><div class="t1dn3z8p"><a class="g9uuari" href="#listing-title" tabindex="0">Przejdź do ofert pracy</a><div><header class="wfrbh1q"><div class="hoafc8e g1cobuf9" data-alignitems="center" data-container="true" data-fullwidth="true" data-test="siteHeader" style="--grid-alignItems:center;--grid-xs:NaN;--grid-sm:NaN;--grid-md:NaN;--grid-lg:NaN;--grid-xl:NaN;--grid-xxl:NaN"><div class="l1tbgngq g1cobuf9" data-container="true" data-is-searchvisible="true" style="--grid-xs:NaN;--grid-sm:NaN;--grid-md:NaN;--grid-lg:NaN;--grid-xl:NaN;--grid-xxl:NaN"><a aria-label="Logo strony, link do strony głównej" class="arcdjpc" data-test="anchor-siteLogo" href="https://theprotocol.it"><svg aria-hidden="true" class="l1ragg9b" fill="none" height="32" role="img" viewbox="0 0 233 32" width="233" xmlns="http://www.w3.org/2000/svg"><path d="M75.0581 21.405C72.6396 21.405 70.7017 19.5049 70.7017 17.0458C70.7017 14.5867 72.6279 12.6866 75.0581 12.6866C77.4882 12.6866 79.3402 14.5867 79.3402 17.0458C79.3402 19.5049 77.4414 21.405 75.0581 21.405ZM75.0581 7.55724C69.5413 7.55724 65.3725 11.5998 65.3725 17.0458V31.9961H70.6353V24.4193C71.7566 25.8307 73.7219 26.5266 75.7223 26.5266C80.6725 26.5266 84.6772 22.5192 84.6772 17.038C84.6772 11.5568 80.5357 7.54942 75.0581 7.54942V7.55724ZM107.842 21.405C105.31 21.405 103.595 19.5792 103.595 17.0458C103.595 14.5124 105.318 12.6866 107.842 12.6866C110.366 12.6866 112.089 14.5124 112.089 17.0458C112.089 19.5792 110.366 21.405 107.842 21.405ZM107.842 7.55724C102.263 7.55724 98.2581 11.4512 98.2581 17.0458C98.2581 22.6404 102.263 26.5344 107.842 26.5344C113.421 26.5344 117.426 22.6404 117.426 17.0458C117.426 11.4512 113.421 7.55724 107.842 7.55724ZM85.8024 17.6401V26.1747H91.0652V17.6401C91.0652 15.0441 92.714 13.1049 95.3121 13.1049H97.5548V7.90128H95.3121C89.4828 7.90128 85.7946 10.5363 85.7946 17.6323L85.8024 17.6401ZM164.346 12.6866C165.994 12.6866 167.542 13.6327 167.999 15.0441H173.476C172.773 10.6184 169.093 7.56115 164.385 7.56115C158.981 7.56115 154.976 11.5685 154.976 17.0497C154.976 22.531 158.981 26.5383 164.385 26.5383C169.093 26.5383 172.773 23.4771 173.476 19.0553H167.999C167.545 20.4667 165.998 21.4128 164.346 21.4128C162.029 21.4128 160.306 19.548 160.306 17.0536C160.306 14.5593 162.029 12.6944 164.346 12.6944V12.6866ZM127.596 2.08772H122.329V6.64239C122.329 7.44777 121.876 7.90519 121.067 7.90519H117.942V12.6827H122.325V18.9693C122.325 23.8837 124.92 26.3428 129.452 26.3428C130.788 26.3428 132.437 26.2685 133.875 26.0652V21.0101C132.402 21.1861 131.343 21.2252 130.538 21.2252C128.471 21.2252 127.592 20.455 127.592 18.4142V12.6905H133.875V7.91301H127.592V2.08772H127.596ZM184.256 21.4089C181.724 21.4089 180.013 19.5831 180.013 17.0497C180.013 14.5163 181.736 12.6905 184.256 12.6905C186.776 12.6905 188.499 14.5163 188.499 17.0497C188.499 19.5831 186.776 21.4089 184.256 21.4089ZM184.256 7.56115C178.677 7.56115 174.672 11.4551 174.672 17.0497C174.672 22.6444 178.677 26.5383 184.256 26.5383C189.835 26.5383 193.84 22.6444 193.84 17.0497C193.84 11.4551 189.835 7.56115 184.256 7.56115ZM195.09 26.1864H200.353V2.08772H195.09V26.1825V26.1864ZM27.6501 7.55724C25.47 7.55724 23. ...
#               </span></div></div></div></div><div class="s1m0yo0k"><button aria-label="Przycisk z ikoną plusa do dodania oferty do ulubionych" class="bsc0o8j swiur52 s1ebmxia w11iwtu0 p54ozpa i1tz4gg9" data-saved="false" data-test="button-saveOffer" type="button"><div class="cqj1vu9 cz5x7hz"><svg aria-hidden="true" class="pc7ehyz" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M2 12C2 6.486 6.486 2 12 2C17.514 2 22 6.486 22 12C22 17.514 17.514 22 12 22C6.486 22 2 17.514 2 12ZM4 12C4 16.411 7.589 20 12 20C16.411 20 20 16.411 20 12C20 7.589 16.411 4 12 4C7.589 4 4 7.589 4 12ZM11 11V7H13V11H17V13H13V17H11V13H7V11H11Z" fill="currentColor" fill-rule="evenodd"></path></svg></div></button></div></div></div><div class="mf4575s g1cobuf9" data-alignitems="center" data-container="true" data-padding-bottom="true" data-small="false" data-wrap="wrap" style="--grid-alignItems:center;--grid-wrap:wrap;--grid-xs:NaN;--grid-sm:NaN;--grid-md:NaN;--grid-lg:NaN;--grid-xl:NaN;--grid-xxl:NaN"><div class="luaczaj" data-small="false"><div class="l1c07yeh"><svg aria-hidden="true" class="is7evx9" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M20 6H17V4C17 2.897 16.103 2 15 2H9C7.897 2 7 2.897 7 4V6H4C2.897 6 2 6.897 2 8V19C2 20.103 2.897 21 4 21H20C21.103 21 22 20.103 22 19V8C22 6.897 21.103 6 20 6ZM16 8V19H8V8H16ZM15 4V6H9V4H15ZM4 8H6V19H4V8ZM18 19V8H20L20.001 19H18Z" fill="#ABABAB"></path></svg><div class="r4179ok bldcnq5 ihmj1ec ts4bie3" data-test="text-employerName">SQUARE ONE RESOURCES sp. z o.o.</div></div><div class="l1c07yeh"><svg aria-hidden="true" class="is7evx9" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M9.00003 2H19C20.103 2 21 2.897 21 4V21C21 21.2652 20.8947 21.5196 20.7071 21.7071C20.5196 21.8946 20.2652 22 20 22H4.00003C3.73481 22 3.48046 21.8946 3.29292 21.7071C3.10539 21.5196 3.00003 21.2652 3.00003 21V16C2.80228 16 2.60898 15.9413 2.44457 15.8314C2.28016 15.7215 2.15202 15.5654 2.07635 15.3827C2.00068 15.2 1.98088 14.9989 2.01945 14.805C2.05802 14.611 2.15322 14.4329 2.29303 14.293L7.00003 9.586V4C7.00003 2.897 7.89703 2 9.00003 2ZM5.00003 20H11V14.414L8.00003 11.414L5.00003 14.414V20ZM13 20H19V4H9.00003V9.586L13.707 14.293C13.8473 14.4327 13.943 14.6109 13.9818 14.805C14.0207 14.9991 14.001 15.2004 13.9252 15.3833C13.8495 15.5662 13.7211 15.7224 13.5563 15.8322C13.3916 15.942 13.198 16.0004 13 16V20ZM13 6H11V8H13V6ZM17 6H15V8H17V6ZM17 10.031H15V12H17V10.031ZM17 14H15V16H17V14ZM9.00003 15H7.00003V17H9.00003V15Z" fill="currentColor" fill-rule="evenodd"></path></svg><div class="r4179ok bldcnq5 ihmj1ec ts4bie3" data-test="text-workModes">remote</div></div></div></div></div></div><div class="scmj0zy g1cobuf9" data-small="false" data-xs="12" style="--grid-xs:1;--grid-sm:NaN;--grid-md:NaN;--grid-lg:NaN;--grid-xl:NaN;--grid-xxl:NaN"><div class="c1lkd2h9" data-test="section-expectedTechnologies"><svg aria-hidden="true" class="igr0jzl" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.37498 16.7812L8.62498 15.2192L4.60098 12.0002L8.62498 8.78123L7.37498 7.21923L2.37498 11.2192C2.25783 11.3129 2.16325 11.4317 2.09825 11.5669C2.03326 11.7021 1.99951 11.8502 1.99951 12.0002C1.99951 12.1502 2.03326 12.2983 2.09825 12.4335C2.16325 12.5687 2.25783 12.6875 2.37498 12.7812L7.37498 16.7812ZM16.625 7.21923L15.375 8.78123L19.399 12.0002L15.375 15.2192L16.625 16.7812L21.625 12.7812C21.7421 12.6875 21.8367 12.5687 21.9017 12.4335C21.9667 12.2983 22.0005 12.1502 22.0005 12.0002C22.0005 11.8502 21.9667 11.7021 21.9017 11.5669C21.8367 11.4317 21.7421 11.3129 21.625 11.2192L16.625 7.21923ZM14.976 3.21623L10.976 21.2162L9.02298 20.7822L13.023 2.78223L14.976 3.21623Z" fill="currentColor"></path></svg><div aria-expanded="false" class="anrrvdm m13o6ws7" data-is-expanded="f ...

# %% [markdown]
# ### rocketjobs.pl - scrape url

# %%
import httpx
rocketjobs = "https://rocketjobs.pl/oferty-pracy/wszystkie-lokalizacje/bi-data?doswiadczenie=staz-junior&praca-zdalna=tak&orderBy=DESC&sortBy=published&from=0"

rocket = httpx.get(rocketjobs, follow_redirects=True)
print(rocket.text)
# Out:
# <!DOCTYPE html><html lang="pl"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, interactive-widget=resizes-content"/><link rel="preload" as="image" href="https://imgproxy.justjoinit.tech/_Od45zPqcL8T70Neq_y9lN58VDOk8kboLkOZAqbBODc/h:200/w:200/plain/https://s3.eu-west-1.amazonaws.com/images.justjoin.it/rocketjobs/company-logos/aa18da5e-0fe7-49dd-b712-363274e595ab%24.jpg"/><link rel="preload" as="image" href="https://imgproxy.justjoinit.tech/7coOkwQ9j6l9iFZUbOjMFoeu_XA6cJzWgvwUxgRZx2U/h:200/w:200/plain/https://public.rocketjobs.pl/companies/logos/original/d6bdaf94408875ce269808f447b4beae752234d7.jpg"/><link rel="stylesheet" href="/_next/static/css/a3933af9e380cac6.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/ac32425c8e1e20a9.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-8aec6626c03b9789.js"/><script src="/_next/static/chunks/a95ca4d7-282d3ad8554ad85d.js" async=""></script><script src="/_next/static/chunks/3386-619c6afdbeb05661.js" async=""></script><script src="/_next/static/chunks/main-app-4ebfaded1a7e48dc.js" async=""></script><script src="/_next/static/chunks/c7064d34-980d55c715ec16db.js" async=""></script><script src="/_next/static/chunks/9cea7886-c6b40b4cf6265070.js" async=""></script><script src="/_next/static/chunks/c6c7db76-ce906916fb4a550d.js" async=""></script><script src="/_next/static/chunks/2db6d1c2-e1ff6327d685dfa7.js" async=""></script><script src="/_next/static/chunks/6c1a3d32-6f43a307d1d007d1.js" async=""></script><script src="/_next/static/chunks/0f3def4a-5d7864449b658227.js" async=""></script><script src="/_next/static/chunks/9827-c1a6bfa8fb56fd21.js" async=""></script><script src="/_next/static/chunks/2308-98f4030a8060698b.js" async=""></script><script src="/_next/static/chunks/9855-8b1f339f50b723b3.js" async=""></script><script src="/_next/static/chunks/9878-a9789aa7667dccb2.js" async=""></script><script src="/_next/static/chunks/5946-36476fc3cbf95cfc.js" async=""></script><script src="/_next/static/chunks/3328-486dcc67779b9694.js" async=""></script><script src="/_next/static/chunks/9927-ecb3d82263672b99.js" async=""></script><script src="/_next/static/chunks/4812-553b4f1e55012791.js" async=""></script><script src="/_next/static/chunks/app/(content)/%5Blocale%5D/layout-cb09203a5ded2236.js" async=""></script><script src="/_next/static/chunks/app/(content)/%5Blocale%5D/%5B%5B...slug%5D%5D/page-52e53d67ac828712.js" async=""></script><script src="/_next/static/chunks/app/(content)/%5Blocale%5D/not-found-72795adb6048a348.js" async=""></script><meta name="color-scheme" content="light"/><link rel="preconnect" href="https://api.rocketjobs.pl"/><link rel="preconnect" href="https://public.rocketjobs.pl/assets"/><link rel="preload" href="https://public.rocketjobs.pl/assets/fonts/ProximaNovaRegular/font.woff" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://public.rocketjobs.pl/assets/fonts/ProximaNovaSemibold/font.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://public.rocketjobs.pl/assets/fonts/ProximaNovaBold/font.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/favicon_rj_16x16.1222e48d.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/favicon_rj_32x32.a66ac835.png"/><link rel="icon" type="image/png" sizes="96x96" href="/_next/static/media/favicon_rj_96x96.46a89038.png"/><!--$--><link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.6.0/slick.min.css"/><link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.6.0/slick-theme.min.css"/><link rel="stylesheet" type="text/css" href="https://cdn.maptiler.com/maptiler-sdk-js/v3.0.1/maptiler-sdk.css"/><script defer="" src="https://id.jus ...
#                 90deg,
#                 transparent,
#                 rgba(0, 0, 0, 0.08),
#                 transparent
#               );content:"";position:absolute;-webkit-transform:translateX(-100%);-moz-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);bottom:0;left:0;right:0;top:0;}.mui-z583t::after{-webkit-animation:animation-wiooy9 2s linear 0.5s infinite;animation:animation-wiooy9 2s linear 0.5s infinite;}.mui-wexlaa{font-weight:500;font-size:10px;line-height:14px;letter-spacing:0;font-family:Archivo,sans-serif;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.mui-wexlaa .MuiTooltip-tooltip{min-height:22px;max-width:300px;color:#FFFFFF;font-weight:500;font-size:10px;line-height:14px;letter-spacing:0;font-family:Archivo,sans-serif;}.mui-1iu1sqy{text-align:center;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;font-size:1.5rem;padding:8px;border-radius:50%;color:rgba(0, 0, 0, 0.24);-webkit-transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;color:#FFFFFF;border-radius:100px;-webkit-transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,-webkit-transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;-webkit-animation:none;animation:none;text-transform:none;white-space:nowrap;min-width:unset;height:40px;width:40px;padding:8px;position:absolute;top:8px;left:8px;display:none;}.mui-1iu1sqy.Mui-disabled{background-color:transparent;color:rgba(0, 0, 0, 0.26);}.mui-1iu1sqy.MuiIconButton-loading{color:transparent;}.mui-1iu1sqy:active{box-shadow:none;-webkit-transform:scale(0.90);-moz-transform:scale(0.90);-ms-transform:scale(0.90);transform:scale(0.90);}.mui-1iu1sqy svg{color:inherit;}.mui-1iu1sqy:focus-visible{box-shadow:0px 0px 0px 4px rgba(0, 0, 0, 0.15);}.mui-1iu1sqy svg{height:24px;width:24px;}.mui-16jxlzu{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;position:relative;box-sizing:border-box;-webkit-tap-highlight-color:transparent;background-color:transparent;outline:0;border:0;margin:0;border-radius:0;padding:0;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-moz-appearance:none;-webkit-appearance:none;-webkit-text-decoration:none;text-decoration:none;color:inherit;text-align:center;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;font-size:1.5rem;padding:8px;border-radius:50%;color:rgba(0, 0, 0, 0.24);-webkit-transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;color:#FFFFFF;border-radius:100px;-webkit-transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,-webkit-transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;-webkit-animation:none;animation:none;text-transform:none;white-space:nowrap;min-width:unset;height:40px;width:40px;padding:8px;position:absolute;top:8px;left:8px;display:none;}.mui-16jxlzu::-moz-focus-inner{border-style:none;}.mui-16jxlzu.Mui-disabled{pointer- ...

# %% [markdown]
# ### justjoin.it - scrape URL

# %%
import httpx
jjit = "https://justjoin.it/job-offers/all-locations/data?experience-level=junior&orderBy=DESC&sortBy=published&keyword=python&from=0&workplace=remote"

jj = httpx.get(jjit)
print(jj.text)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, interactive-widget=resizes-content"/><link rel="preload" as="image" href="https://imgproxy.justjoinit.tech/ZVKXog7e4Fi-XIADeB7xrvagj8a_QT6Uxbr7KBi-mmw/h:200/w:200/plain/https://public.justjoin.it/companies/logos/original/8b1cf467aa77e07c48bdc1666c5a009ecc37e448.png"/><link rel="preload" as="image" href="https://imgproxy.justjoinit.tech/W3BaosCyAvmcjiNS7iIOXjIATxu7Ihk2wDyZvP8cF18/h:200/w:200/plain/https://imgproxy.justjoinit.tech/TRkeRk1ACuZFz1iEdo-wqxv2qFXDMhSDxtA_aOE4dGU/h:200/w:200/plain/https://imgproxy.justjoinit.tech/Y2DbNwdN2M97T3hea_JdFl5MLTJDHkq_0D46thkI_WM/h:200/w:200/plain/https://imgproxy.justjoinit.tech/pY4kBZ1ailQfJqfQbC2XEjJLsZQTqE8fYNA_h-ZU6F4/h:200/w:200/plain/https://public.justjoin.it/offers/company_logos/original/ab2bf472c48ec395d6f79b3f50b5a73d33eec051.jpeg"/><link rel="preload" as="image" href="https://imgproxy.justjoinit.tech/WrcgXuJ_2emB9anYZQifIrpAfKboM2gB4Cgs_NrLyV0/h:200/w:200/plain/https://public.justjoin.it/companies/logos/original/d56540de4d486449fe3fa4e2496504df901a5cf8.png"/><link rel="preload" as="image" href="https://imgproxy.justjoinit.tech/60whyb0uk5HINUSVFouwrXbmgQI4O1oZdlEH7VdBcMU/h:200/w:200/plain/https://opensignal.traffit.com/api/file/publicFileContent/5750"/><link rel="stylesheet" href="/_next/static/css/a3933af9e380cac6.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/ac32425c8e1e20a9.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-8aec6626c03b9789.js"/><script src="/_next/static/chunks/a95ca4d7-282d3ad8554ad85d.js" async=""></script><script src="/_next/static/chunks/3386-619c6afdbeb05661.js" async=""></script><script src="/_next/static/chunks/main-app-4ebfaded1a7e48dc.js" async=""></script><script src="/_next/static/chunks/c7064d34-980d55c715ec16db.js" async=""></script><script src="/_next/static/chunks/9cea7886-c6b40b4cf6265070.js" async=""></script><script src="/_next/static/chunks/c6c7db76-ce906916fb4a550d.js" async=""></script><script src="/_next/static/chunks/2db6d1c2-e1ff6327d685dfa7.js" async=""></script><script src="/_next/static/chunks/6c1a3d32-6f43a307d1d007d1.js" async=""></script><script src="/_next/static/chunks/0f3def4a-5d7864449b658227.js" async=""></script><script src="/_next/static/chunks/9827-c1a6bfa8fb56fd21.js" async=""></script><script src="/_next/static/chunks/2308-98f4030a8060698b.js" async=""></script><script src="/_next/static/chunks/9855-8b1f339f50b723b3.js" async=""></script><script src="/_next/static/chunks/9878-a9789aa7667dccb2.js" async=""></script><script src="/_next/static/chunks/5946-36476fc3cbf95cfc.js" async=""></script><script src="/_next/static/chunks/3328-486dcc67779b9694.js" async=""></script><script src="/_next/static/chunks/9927-ecb3d82263672b99.js" async=""></script><script src="/_next/static/chunks/4812-553b4f1e55012791.js" async=""></script><script src="/_next/static/chunks/app/(content)/%5Blocale%5D/layout-cb09203a5ded2236.js" async=""></script><script src="/_next/static/chunks/app/(content)/%5Blocale%5D/%5B%5B...slug%5D%5D/page-52e53d67ac828712.js" async=""></script><script src="/_next/static/chunks/app/(content)/%5Blocale%5D/not-found-72795adb6048a348.js" async=""></script><meta name="color-scheme" content="light"/><link rel="preconnect" href="https://api.justjoin.it"/><link rel="preconnect" href="https://public.justjoin.it"/><link rel="preload" href="https://public.justjoin.it/fonts/open-sans/open-sans-v34-latin_latin-ext-regular.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://public.justjoin.it/fonts/open-sans/open-sans-v34-latin_latin-ext-600.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://public.justjoin.it/fonts/open-sans/open-sans-v34-latin_latin-ext-700.woff2" as="font" type="font/woff2" crossorigin=""/><l ...
#                 90deg,
#                 transparent,
#                 rgba(36, 34, 39, 0.08),
#                 transparent
#               );content:"";position:absolute;-webkit-transform:translateX(-100%);-moz-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);bottom:0;left:0;right:0;top:0;}.mui-1uavo7n::after{-webkit-animation:animation-wiooy9 2s linear 0.5s infinite;animation:animation-wiooy9 2s linear 0.5s infinite;}.mui-an725y{font-weight:600;font-size:10px;line-height:14px;letter-spacing:0;font-family:Inter;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.mui-an725y .MuiTooltip-tooltip{min-height:22px;max-width:300px;color:#FFFFFF;font-weight:600;font-size:10px;line-height:14px;letter-spacing:0;font-family:Inter;}.mui-1t9v4dp{text-align:center;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;font-size:1.5rem;padding:8px;border-radius:50%;color:rgba(36, 34, 39, 0.24);-webkit-transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;color:#FFFFFF;border-radius:100px;-webkit-transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,-webkit-transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;-webkit-animation:none;animation:none;text-transform:none;white-space:nowrap;min-width:unset;height:40px;width:40px;padding:8px;border:2px solid rgba(255, 255, 255, 0.50);color:#2D2B30;background:rgba(255, 255, 255, 0.10);box-shadow:0px -2px 8px 0px rgba(255, 255, 255, 0.40) inset,0px 4px 20px 0px rgba(0, 0, 0, 0.10);-webkit-backdrop-filter:blur(12px);backdrop-filter:blur(12px);position:absolute;top:8px;left:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.mui-1t9v4dp.Mui-disabled{background-color:transparent;color:rgba(36, 34, 39, 0.26);}.mui-1t9v4dp.MuiIconButton-loading{color:transparent;}.mui-1t9v4dp:active{box-shadow:none;-webkit-transform:scale(0.90);-moz-transform:scale(0.90);-ms-transform:scale(0.90);transform:scale(0.90);}.mui-1t9v4dp svg{color:inherit;}.mui-1t9v4dp:focus-visible{box-shadow:0px 0px 0px 4px rgba(0, 0, 0, 0.15);}.mui-1t9v4dp svg{height:24px;width:24px;}.mui-1t9v4dp:hover,.mui-1t9v4dp:focus-visible{box-shadow:0px -2px 8px 0px rgba(255, 255, 255, 0.60) inset,0px 4px 10px 0px rgba(0, 0, 0, 0.20);}.mui-1t9v4dp.Mui-disabled{color:#8E8D8F;box-shadow:none;}.mui-wvgtdh{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;position:relative;box-sizing:border-box;-webkit-tap-highlight-color:transparent;background-color:transparent;outline:0;border:0;margin:0;border-radius:0;padding:0;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-moz-appearance:none;-webkit-appearance:none;-webkit-text-decoration:none;text-decoration:none;color:inherit;text-align:center;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;font-size:1.5rem;padding:8px;border-radius:50%;color:rgba(36, 34, 39, 0.24);-webkit-transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-color 150ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;color:#FFFFFF;border-radius:100px;-webkit-transition:background-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,box-shadow 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,outline-color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,color 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms,-webkit-transform 100ms cubic-bezier(0.4, 0, 0.2, 1) 0ms;transition:background-colo ...

# %% [markdown]
# #### Solidjobs - scrape all records - filter from url
# Poprawnie filtruje wszystko

# %%
# test_link_all_params = "https://solid.jobs/offers/it;cities=Krak%C3%B3w,Praca%20zdalna,Warszawa;categories=Programista;experiences=Regular,Junior;minimumSalary=3000;subcategories=Python"
# test_link_all_params = "https://solid.jobs/offers/it;cities=Krak%C3%B3w,Praca%20zdalna,Warszawa;categories=Tester;experiences=Regular,Junior;minimumSalary=3000;subcategories=In%C5%BCynier%20test%C3%B3w%20automatycznych"
test_link_all_params = "https://solid.jobs/offers/it;experiences=Senior;cities=Tr%C3%B3jmiasto;categories=Analityk;minimumSalary=25500"
import urllib.parse
import httpx
def parse_url_params(url):
    """Parse filter parameters from URL."""
    params = {}
    parts = url.split(';')
    for part in parts:
        if '=' in part:
            key, value = part.split('=', 1)
            decoded_value = urllib.parse.unquote(value)
            if key == "cities" and "Trójmiasto" in decoded_value:
                decoded_value = decoded_value.replace("Trójmiasto", "Gdańsk,Gdynia,Sopot")
            params[key] = decoded_value
    print(params)
    return params

def filter_offers(offers, cities=None, categories=None, subcategories=None, experiences=None, minimumSalary=None):
    """Filter job offers by parameters."""
    filtered = []
    for offer in offers:
        if cities:
            city_list = cities.split(',')
            remote_values = ["W całości", "Możliwa w całości"]
            is_remote = offer.get("remotePossible") in remote_values
            city = offer.get("companyCity") in city_list
            
            is_fully_remote = "Praca zdalna" in city_list and is_remote
            invalid_location = not(is_fully_remote or city)
            if invalid_location:
                continue # skip record
        if categories and offer.get("mainCategory") != categories:
            continue # skip record
        if subcategories and offer.get("subCategory") != subcategories:
            continue # skip record
        if experiences:
            exp_list = experiences.split(',')
            if offer.get("experienceLevel") not in exp_list:
                continue # skip record
        salary = offer.get("salaryRange", {})

        is_salary_below_minimum = minimumSalary and (salary["upperBound"] < float(minimumSalary))
        if is_salary_below_minimum:
            continue # skip record
        filtered.append(offer)
    return filtered

def get_all_offers():
    solidjobs = 'https://solid.jobs/api/offers?division=it&sortOrder=default'
    headers = {
        "Accept": "application/vnd.solidjobs.jobofferlist+json, application/json, text/plain, */*",
    }
    solid = httpx.get(solidjobs, headers=headers)
    return solid.json()


params = parse_url_params(test_link_all_params)
offers = get_all_offers()
filtered_offers = filter_offers(offers, **params)
# import json
# print(json.dumps(filtered_offers, ensure_ascii=False, indent=4))
print(len(filtered_offers))
for offer in filtered_offers:
    print(offer['id'], offer['jobTitle'], offer['companyName'], offer['companyCity'], offer['experienceLevel'])
# Out:
# {'experiences': 'Senior', 'cities': 'Gdańsk,Gdynia,Sopot', 'categories': 'Analityk', 'minimumSalary': '25500'}
# 1
# 24017 Expert IT Analyst (Payments) emagine Gdańsk Senior
